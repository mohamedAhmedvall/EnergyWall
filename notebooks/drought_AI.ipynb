# %% [markdown]
# Here we gonna check datasets about droughness from datacenters

# %%
from datasets import load_dataset

ds = load_dataset("PengfeiLi/WaterEfficientDatasetForAfricanCountries")
